# %% [markdown]
# # Работа с базами данных

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 6: Работа с базами данных
# * https://sqliteonline.com/
# * https://docs.python.org/3/library/sqlite3.html
# * https://www.geeksforgeeks.org/sql-join-set-1-inner-left-right-and-full-joins/
# * https://www.datacamp.com/community/tutorials/group-by-having-clause-sql

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Работая с базой данных `Chinook_Sqlite.sqlite`, найдите и выведите на экран имена и фамилии всех заказчиков из Канады

# %% [markdown]
# 2. Найти и вывести на экран названия всех альбомов группы Accept

# %% [markdown]
# 3. Создайте базу данных с названием вашей группы. В этой базе данных создайте таблицу Student, содержащую 2 столбца: id и name. Добавьте в таблицу Student информацию о студентах, сидящих с вами по соседству.

# %% [markdown]
# ## Лабораторная работа 6

# %% [markdown]
# 1. Создайте файл базы данных c названием `recipes.db`. Создайте объект-курсор.

# %%
import  sqlite3

# %%
con = sqlite3.connect("./resource/recipes.db")
cur = con.cursor()

# %% [markdown]
# 2. Напишите и выполните SQL-запрос для создания таблицы рецептов `Recipe`. Таблица должна содержать следующие поля:
# `id`, `name`, `minutes`, `submitted`, `description`, `n_ingredients`. Определитесь с типами и составом ключевых полей.

# %%
# cur.execute('DROP TABLE Recipe')
# cur.execute('DROP TABLE Review')

# %%
cur.execute('''CREATE TABLE Recipe 
               (id INTEGER PRIMARY KEY NOT NULL, 
               name VARCHAR(200), 
               minutes INTEGER, 
               submitted VARCHAR(10), 
               description VARCHAR(1000), 
               n_ingredients INTEGER)''')

# %% [markdown]
# 3. Напишите и выполните SQL-запрос для создания таблицы отзывов `Review`. Таблица должна содержать следующие поля:
# `id`, `user_id`, `recipe_id`, `date`, `rating`, `review`. Определитесь с типами полей, набором ключевых полей. При помощи внешнего ключа соедините две таблицы.

# %%
cur.execute('''CREATE TABLE Review 
               (id INTEGER PRIMARY KEY NOT NULL, 
               user_id INTEGER, 
               recipe_id INTEGER,
               date VARCHAR(10), 
               rating REAL, 
               review VARCHAR(1000),
               FOREIGN KEY (recipe_id) REFERENCES Recipe(id))''')

# %% [markdown]
# 4. Загрузите данные из файлов `reviews_sample.csv` (__ЛР2__) и `recipes_sample_with_tags_ingredients.csv` (__ЛР5__) в созданные таблицы

# %%
import csv

# %%
with open('../sem02/data/reviews_sample.csv') as fp2:
    reader2 = csv.reader(fp2)
    res = [row for row in reader2][:3]

# %%
with open('../sem05/result/recipes_sample_with_tags_ingredients.csv') as fp5:
    reader5 = csv.reader(fp5)
    res = [row for row in reader5][:3]

# %%
with open('../sem05/result/recipes_sample_with_tags_ingredients.csv') as fp5:
    reader5 = csv.reader(fp5)
    header = next(reader5) 
    for _, name, id, minutes, contributor_id, submitted, n_steps, description, n_ingredients, ingredients in reader5:
        cur.execute('INSERT INTO Recipe (id, name, minutes, submitted, description, n_ingredients) VALUES (?,?,?,?,?,?)', 
                (id, name, minutes, submitted, description, n_ingredients))
        
        
# проверка 
for row in cur.execute('SELECT * FROM Recipe LIMIT 0, 3'):
    print(row)
# Out:
# (48, 'boston cream pie', 135, '1999-08-24', '', 15)
# (55, 'betty crocker s southwestern guacamole dip', 125, '1999-09-15', '', 5)
# (66, 'black coffee barbecue sauce', 30, '1999-09-10', "it's great to know folks like this sauce so much! i wish i could take credit for it but it was adopted after the original member left. thank you, all, just the same.\ni have made the recipe with regular brewed coffee but highly recommend the espresso. in a pinch use strong instant if you have nothing else. the acid of the coffee balances the sweetness of the other ingredients.", 11)

# %%
with open('../sem02/data/reviews_sample.csv') as fp2:
    reader2 = csv.reader(fp2)
    header = next(reader2) 
    for _, user_id, recipe_id, date, rating, review in reader2:
        cur.execute('INSERT INTO Review (id, user_id, recipe_id, date, rating, review) VALUES (?,?,?,?,?,?)', 
                (_, user_id, recipe_id, date, rating, review))
        
        
# проверка
for row in cur.execute('SELECT * FROM Review LIMIT 0, 3'):
    print(row)
# Out:
# (5, 52282, 120345, '2005-05-21', 4.0, "very very sweet. after i waited the 2 days i bought 2 more pints of raspberries and added them to the mix. i'm going to add some as a cake filling today and will take a photo.")
# (6, 124416, 120345, '2011-08-06', 0.0, 'Just an observation, so I will not rate.  I followed this procedure with strawberries instead of raspberries.  Perhaps this is the reason it did not work well.  Sorry to report that the strawberries I did in August were moldy in October.  They were stored in my downstairs fridge, which is very cold and infrequently opened.  Delicious and fresh-tasting prior to that, though.  So, keep a sharp eye on them.  Personally I would not keep them longer than a month.  This recipe also appears as #120345 posted in July 2009, which is when I tried it.  I also own the Edna Lewis cookbook in which this appears.')
# (7, 2000192946, 120345, '2015-05-10', 2.0, 'This recipe was OVERLY too sweet.  I would start out with 1/3 or 1/4 cup of sugar and jsut add on from there.  Just 2 cups was way too much and I had to go back to the grocery store to buy more raspberries because it made so much mix.  Overall, I would but the long narrow box or raspberries.  Its a perfect fit for the recipe plus a little extra.  I was not impressed with this recipe.  It was exceptionally over-sweet.  If you make this simple recipe, MAKE SURE TO ADD LESS SUGAR!')

# %% [markdown]
# 5. Найдите все рецепты, для выполнения которых нужно ровно 10 ингредиентов. Выведите на экран первые 5 из найденных рецептов.

# %%
seq = cur.execute('''SELECT * FROM Recipe 
                        WHERE n_ingredients = 10
                        LIMIT 0, 5''')

seq.fetchall()
# Out:
# [(246, 'lee s hot crab dip', 45, '1999-09-01', "lee's hot crab dip", 10),
#  (289,
#   'feijoada  brazilian bean soup  ii',
#   150,
#   '1999-10-04',
#   'brazilian bean soup',
#   10),
#  (544, 'greek mushroom salad', 38, '1999-08-10', '', 10),
#  (671, 'cucumber relish', 40, '1999-09-10', '', 10),
#  (975,
#   'basil parmesan biscuits',
#   27,
#   '1999-08-14',
#   'perfect with pasta or other italian dishes',
#   10)]

# %% [markdown]
# 6. Найдите название рецепта, для выполнения которого требуется больше всего времени.

# %%
seq = cur.execute('''SELECT name FROM Recipe 
                        WHERE minutes IN 
                            (SELECT MAX(minutes) FROM Recipe) ''')

seq.fetchall()
# Out:
# [('strawberry liqueur',), ('blueberry liqueur',)]

# %% [markdown]
# 7. Запросите у пользователя id рецепта и верните информацию об этом рецепте. Если рецепт отсуствует, выведите соответствующее сообщение.

# %%
def user_input():
    id_ = input("Введите id: ")
    try:
        id_ = int(id_)
        return id_
    except ValueError:
        print('Введите число типа int')
        return user_input()

# %%
id_ = user_input()
seq = cur.execute(f'SELECT * FROM Recipe WHERE id = {id_}',)  
rez = seq.fetchone()
if not rez:
    print(f'Рецепт с id = {id_} отсутствует')
else:
    print(rez)
    
# введите 57993
# Out:
# Введите id: 57993
# (57993, 'salmon with tomatoes', 50, '2003-04-04', 'this savoury dish is very popular in andalusia, spain. you can use red pepper flakes (to your taste) in place of the hot pepper and any firm whitefish can be a substitute for the salmon. great with rice and a green vegetable.', 13)

# %% [markdown]
# 8. Найдите кол-во отзывов с рейтингом 5.

# %%
seq = cur.execute('''SELECT COUNT(*) FROM Review
                        WHERE rating = 5''')

seq.fetchall()
# Out:
# [(91361,)]

# %% [markdown]
# 9. Найдите кол-во уникальных рецептов, не имеющих отзывов с рейтингом, меньше 4.

# %%
seq = cur.execute('''SELECT COUNT(DISTINCT name) FROM Recipe
                        WHERE id IN
                            (SELECT recipe_id FROM Review
                                WHERE rating >= 4)''')

seq.fetchall()
# Out:
# [(26297,)]

# %% [markdown]
# 10. Найдите кол-во рецептов, опубликованных в 2010 году и имеющих длину не менее 15 минут.

# %%
seq = cur.execute('''SELECT COUNT(*) FROM Recipe
                        WHERE strftime('%Y', submitted) = '2010' AND
                        minutes >= 15''')

# %%
seq.fetchall()
# Out:
# [(1319,)]

# %% [markdown]
# 11. Выберите id рецепта, название рецепта, id пользователя, оставившего отзыв, дату отзыва и рейтинг для тех рецептов, которые имеют не менее 3 ингредиентов. Отсортируйте результат по id рецепта.

# %%
seq = cur.execute('''SELECT rc.id, rc.name, rv.user_id, rv.date, rv.rating
                        FROM Recipe rc
                        INNER JOIN Review rv
                        ON rc.id = rv.recipe_id
                        WHERE rc.n_ingredients >= 3
                        ''')

seq.fetchall()
# Out:
# [(134728, 'kfc honey bbq strips', 76535, '2005-09-02', 4.0),
#  (134728, 'kfc honey bbq strips', 273745, '2005-12-22', 5.0),
#  (134728, 'kfc honey bbq strips', 190375, '2007-03-09', 5.0),
#  (134728, 'kfc honey bbq strips', 468945, '2008-02-20', 0.0),
#  (134728, 'kfc honey bbq strips', 255338, '2008-04-11', 5.0),
#  (134728, 'kfc honey bbq strips', 1171894, '2009-04-21', 5.0),
#  (200236,
#   'lamb stew with tomatoes  chickpeas and spices',
#   68960,
#   '2006-12-19',
#   4.0),
#  (200236,
#   'lamb stew with tomatoes  chickpeas and spices',
#   618928,
#   '2007-10-17',
#   4.0),
#  (200236,
#   'lamb stew with tomatoes  chickpeas and spices',
#   217118,
#   '2008-04-18',
#   5.0),
#  (41090, 'black and white bean salad', 58332, '2003-02-25', 4.0),
#  (145160, 'thanksgiving mashed potatoes', 263525, '2005-11-17', 5.0),
#  (180132, 'chicken vegetable soup low carb low fat', 58439, '2007-06-09', 4.0),
#  (181765, 'alabama white barbecue bbq sauce', 52476, '2006-08-15', 5.0),
#  (181765, 'alabama white barbecue bbq sauce', 37722, '2007-03-12', 5.0),
#  (228530, 'bulgur and pumpkin pilaf', 1320855, '2009-07-12', 5.0),
#  (228530, 'bulgur and pumpkin pilaf', 345569, '2009-10-05', 5.0),
#  (228530, 'bulgur and pumpkin pilaf', 278578, '2010-10-03', 5.0),
#  (441096, 'pumpkin chili', 422608, '2016-02-26', 5.0),
#  (116953, 'freezer ready streusel mix', 107135, '2005-04-14', 5.0),
#  (116953, 'freezer ready streusel mix', 209441, '2005-05-12', 5.0),
#  (116953, 'freezer ready streusel mix', 52543, '2005-05-12', 5.0),
#  (116953, 'freezer ready streusel mix', 235751, '2005-08-28', 5.0),
#  (273416, 'applesauce muffins', 73746, '2010-04-12', 5.0),
#  (336795,
#   'caramelized onion  gruyere  and spinach crustless quiche',
#   645231,
#   '2008-11-28',
#   5.0),
#  (336795,
#   'caramelized onion  gruyere  and spinach crustless quiche',
#   200862,
#   '2011-11-05',
#   5.0),
#  (336795,
#   'caramelized onion  gruyere  and spinach crustless quiche',
#   2001848839,
#   '2017-12-10',
#   0.0),
#  (373842, 'quick quiche lorraine', 107583, '2009-12-05', 5.0),
#  (373842, 'quick quiche lorraine', 487088, '2013-02-03', 5.0),
#  (373842, 'quick quiche lorraine', 461834, '2013-09-22', 5.0),
#  (373842, 'quick quiche lorraine', 176615, '2014-07-02', 5.0),
#  (373842, 'quick quiche lorraine', 2000688819, '2015-11-17', 5.0),
#  (373842, 'quick quiche lorraine', 615758, '2018-06-24', 5.0),
#  (381108, 'creamy ham  potato   corn casserole', 655199, '2009-07-15', 3.0),
#  (229942, 'injera', 1145795, '2009-01-26', 5.0),
#  (52968, 'extra cheesy macaroni   cheese', 41578, '2003-04-03', 5.0),
#  (52968, 'extra cheesy macaroni   cheese', 42337, '2003-04-13', 0.0),
#  (52968, 'extra cheesy macaroni   cheese', 162939, '2006-09-16', 5.0),
#  (77021, 'chicken raviolini soup', 68460, '2003-12-20', 4.0),
#  (77021, 'chicken raviolini soup', 41578, '2005-09-20', 5.0),
#  (77021, 'chicken raviolini soup', 75497, '2008-01-08', 3.0),
#  (92154, 'broiled soft shelled crabs', 149342, '2004-07-05', 3.0),
#  (92154, 'broiled soft shelled crabs', 223979, '2009-01-12', 5.0),
#  (359677, 'red beans with bell pepper', 743849, '2009-06-22', 5.0),
#  (33205, 'homemade vanilla wafer cookies', 6357, '2002-07-09', 3.0),
#  (33205, 'homemade vanilla wafer cookies', 650039, '2008-01-27', 4.0),
#  (88682, 'swiss cheese potato bake', 41578, '2005-02-12', 5.0),
#  (353952, 'chicken with tortellini and broccoli', 1358170, '2009-08-20', 5.0),
#  (426090, 'indian style green beans', 424680, '2010-05-29', 5.0),
#  (426090, 'indian style green beans', 527886, '2010-05-31', 3.0),
#  (426090, 'indian style green beans', 383346, '2010-05-31', 5.0),
#  (426090, 'indian style green beans', 895132, '2010-06-01', 5.0),
#  (426090, 'indian style green beans', 29655, '2010-06-02', 5.0),
#  (426090, 'indian style green beans', 143721, '2012-08-17', 5.0),
#  (426090, 'indian style green beans', 166642, '2012-08-18', 5.0),
#  (426090, 'indian style green beans', 690623, '2017-08-14', 5.0),
#  (426090, 'indian style green beans', 227978, '2017-08-15', 5.0),
#  (426090, 'indian style green beans', 226863, '2017-08-15', 5.0),
#  (426090, 'indian style green beans', 305531, '2017-08-20', 5.0),
#  (426090, 'indian style green beans', 482376, '2018-02-09', 5.0),
#  (77001, 'caramelized nuts', 50472, '2003-12-19', 5.0),
#  (77001, 'caramelized nuts', 47892, '2007-11-16', 5.0),
#  (77001, 'caramelized nuts', 1091591, '2008-12-22', 5.0),
#  (77001, 'caramelized nuts', 1215879, '2009-03-25', 5.0),
#  (77001, 'caramelized nuts', 125356, '2012-01-16', 5.0),
#  (337682, 'cinnamon chocolate chip cake', 1900993, '2012-04-17', 5.0),
#  (16127, 'napa cabbage steak', 95743, '2004-05-23', 5.0),
#  (166852, 'potsie s white trash trinity', 21752, '2007-03-26', 4.0),
#  (166852, 'potsie s white trash trinity', 171084, '2007-06-10', 5.0),
#  (166852, 'potsie s white trash trinity', 2324285, '2012-12-11', 5.0),
#  (232036, 'hungarian cabbage rolls', 726381, '2008-01-13', 0.0),
#  (232046, 'oil free four bean salad', 2001454217, '2018-07-12', 4.0),
#  (232053, 'oven fried cajun chicken breasts', 39334, '2008-02-10', 5.0),
#  (113577, 'thanksgiving turkey gobblers  for dogs', 985030, '2008-10-11', 3.0),
#  (89619,
#   'delicious indian spicy chicken sandwich filling',
#   37080,
#   '2004-06-01',
#   5.0),
#  (89619,
#   'delicious indian spicy chicken sandwich filling',
#   101275,
#   '2004-06-10',
#   5.0),
#  (55649, 'balsamic port drizzle', 49304, '2003-03-22', 5.0),
#  (217774, 'mary s creamy peanut butter pie', 679953, '2009-02-03', 5.0),
#  (291490, 'chocolate mint bars  a lighter version', 693345, '2010-06-21', 5.0),
#  (291490,
#   'chocolate mint bars  a lighter version',
#   1179225,
#   '2011-06-08',
#   5.0),
#  (410749, 'lower calorie quick hot fudge', 2777037, '2013-04-09', 3.0),
#  (55649, 'balsamic port drizzle', 58538, '2003-05-25', 5.0),
#  (55649, 'balsamic port drizzle', 83093, '2007-03-08', 5.0),
#  (55649, 'balsamic port drizzle', 222564, '2010-11-29', 5.0),
#  (273854, 'awesome chicken buffalo dip', 538563, '2008-12-23', 5.0),
#  (305675, 'chicken dner kebab', 174096, '2010-01-17', 5.0),
#  (305675, 'chicken dner kebab', 1802533639, '2014-02-27', 5.0),
#  (216162, 'chocolate marmalade biscotti', 619965, '2008-01-24', 5.0),
#  (231028, 'lunch box fillers   carrot stix', 207176, '2007-05-30', 0.0),
#  (231028, 'lunch box fillers   carrot stix', 64667, '2007-06-04', 4.0),
#  (231028, 'lunch box fillers   carrot stix', 362983, '2007-06-28', 5.0),
#  (326843, 'spicy season salt', 653438, '2011-03-19', 4.0),
#  (326843, 'spicy season salt', 2342357, '2012-07-26', 0.0),
#  (387741,
#   'jerk wings with ranch dipping sauce   low carb',
#   131349,
#   '2009-12-16',
#   4.0),
#  (472331,
#   'cranberry walnut oatmeal cookies  vegan   gluten free',
#   384918,
#   '2013-03-29',
#   5.0),
#  (472331,
#   'cranberry walnut oatmeal cookies  vegan   gluten free',
#   1802793382,
#   '2014-06-03',
#   5.0),
#  (472331,
#   'cranberry walnut oatmeal cookies  vegan   gluten free',
#   2001977923,
#   '2018-02-06',
#   5.0),
#  (472331,
#   'cranberry walnut oatmeal cookies  vegan   gluten free',
#   2002138361,
#   '2018-05-02',
#   5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 871008, '2008-07-24', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 801865, '2009-06-10', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 848136, '2009-07-03', 4.0),
#  (237164, 'eggplant parmigiana   weight watchers', 965414, '2009-07-16', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 1041886, '2009-08-31', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 54678, '2009-10-30', 4.0),
#  (237164, 'eggplant parmigiana   weight watchers', 666947, '2009-12-09', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 450571, '2010-06-06', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 213407, '2010-07-21', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 1235658, '2011-08-09', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 243474, '2011-11-25', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 41218, '2012-07-19', 5.0),
#  (237164, 'eggplant parmigiana   weight watchers', 1362457, '2013-01-11', 3.0),
#  (237164, 'eggplant parmigiana   weight watchers', 1179225, '2015-03-02', 4.0),
#  (237164, 'eggplant parmigiana   weight watchers', 227652, '2017-01-14', 5.0),
#  (237164,
#   'eggplant parmigiana   weight watchers',
#   2001341923,
#   '2017-02-19',
#   3.0),
#  (237164,
#   'eggplant parmigiana   weight watchers',
#   2002182126,
#   '2018-06-10',
#   5.0),
#  (247641,
#   'eagle brand double delicious cookie bars',
#   1928828,
#   '2011-06-10',
#   0.0),
#  (247641,
#   'eagle brand double delicious cookie bars',
#   1802999449,
#   '2014-08-05',
#   5.0),
#  (9054, 'leftover mashed potato pancakes', 2002084345, '2018-03-30', 1.0),
#  (109578, 'double chocolate cherry cake', 198238, '2005-02-28', 5.0),
#  (109578, 'double chocolate cherry cake', 89831, '2006-11-29', 5.0),
#  (109578, 'double chocolate cherry cake', 169430, '2007-04-08', 4.0),
#  (109578, 'double chocolate cherry cake', 382071, '2007-07-04', 3.0),
#  (17083, 'yummy banana bread', 50315, '2005-12-22', 5.0),
#  (99672, 'citrus chicken with vegetables', 424680, '2008-02-21', 5.0),
#  (99672, 'citrus chicken with vegetables', 1807042, '2011-01-26', 5.0),
#  (116672, '5 minute chili', 2311662, '2012-07-01', 5.0),
#  (41230, 'plum   date chutney', 424680, '2008-11-13', 5.0),
#  (117187, 'texas  chicken fried steak and gravy', 53002, '2011-03-31', 5.0),
#  (434181,
#   'quinoa  garbanzo   spinach salad w  smoked paprika dressing',
#   539686,
#   '2011-06-07',
#   5.0),
#  (434181,
#   'quinoa  garbanzo   spinach salad w  smoked paprika dressing',
#   47892,
#   '2013-05-14',
#   5.0),
#  (434181,
#   'quinoa  garbanzo   spinach salad w  smoked paprika dressing',
#   57222,
#   '2013-05-26',
#   5.0),
#  (434181,
#   'quinoa  garbanzo   spinach salad w  smoked paprika dressing',
#   486725,
#   '2014-03-11',
#   4.0),
#  (441733, 'pot luck chicken', 227978, '2010-11-29', 4.0),
#  (278695, 'puck s packet o  fish', 832955, '2009-02-13', 5.0),
#  (306351, 'israeli kabobs', 171303, '2009-08-20', 4.0),
#  (306351, 'israeli kabobs', 56061, '2009-09-08', 5.0),
#  (306351, 'israeli kabobs', 1470474, '2009-12-03', 0.0),
#  (360, 'baked zucchini frittatas', 14000, '2002-01-17', 5.0),
#  (70671, 'chicken with orange and honey', 60575, '2004-01-10', 5.0),
#  (70671, 'chicken with orange and honey', 315684, '2006-05-04', 5.0),
#  (70671, 'chicken with orange and honey', 725448, '2008-01-12', 4.0),
#  (70671, 'chicken with orange and honey', 559414, '2008-05-24', 5.0),
#  (53272, 'harvest sausage soup', 63128, '2003-08-30', 0.0),
#  (53272, 'harvest sausage soup', 66008, '2007-03-23', 5.0),
#  (533575, 'red stripe chicken', 2001722458, '2017-09-20', 5.0),
#  (120865, 'best ever  gingerbread', 230102, '2005-11-05', 5.0),
#  (120865, 'best ever  gingerbread', 570804, '2008-04-30', 5.0),
#  (29467, 'rosie s sweet and sour meatballs', 38049, '2002-09-09', 0.0),
#  (161887, 'chicken noodle soup with a lady s kick', 313076, '2006-04-23', 5.0),
#  (161887, 'chicken noodle soup with a lady s kick', 56734, '2006-08-20', 4.0),
#  (161887,
#   'chicken noodle soup with a lady s kick',
#   1012643,
#   '2009-02-20',
#   5.0),
#  (56516, 'peppermint patty hot chocolate', 276837, '2005-12-24', 2.0),
#  (56516, 'peppermint patty hot chocolate', 33159, '2006-12-26', 4.0),
#  (192698,
#   'sausage stuffed portabella mushrooms with mozzarella cheese',
#   405761,
#   '2007-01-25',
#   5.0),
#  (192698,
#   'sausage stuffed portabella mushrooms with mozzarella cheese',
#   311566,
#   '2007-02-12',
#   5.0),
#  (192698,
#   'sausage stuffed portabella mushrooms with mozzarella cheese',
#   465872,
#   '2009-01-22',
#   5.0),
#  (192698,
#   'sausage stuffed portabella mushrooms with mozzarella cheese',
#   1803587929,
#   '2014-12-31',
#   5.0),
#  (192698,
#   'sausage stuffed portabella mushrooms with mozzarella cheese',
#   1802421864,
#   '2018-05-23',
#   5.0),
#  (196493, 'shrimp and crawfish creole', 248640, '2007-04-21', 5.0),
#  (196493, 'shrimp and crawfish creole', 740430, '2011-03-13', 3.0),
#  (233853, 'sonoma diet   hummus', 427184, '2008-09-02', 5.0),
#  (17088, 'five hour beef stew', 28862, '2002-01-17', 4.0),
#  (17088, 'five hour beef stew', 15023, '2002-01-29', 5.0),
#  (258451, 'citrus salad dressing', 83093, '2008-02-25', 5.0),
#  (258451, 'citrus salad dressing', 197023, '2009-03-02', 5.0),
#  (258451, 'citrus salad dressing', 1641166, '2010-06-26', 0.0),
#  (258451, 'citrus salad dressing', 2894864, '2013-07-08', 5.0),
#  (406171,
#   'sarasota s supreme smoky scalloped potatoes   ham',
#   758101,
#   '2009-12-31',
#   4.0),
#  (11967, 'italian pot roast', 55461, '2002-09-30', 5.0),
#  (406171,
#   'sarasota s supreme smoky scalloped potatoes   ham',
#   790231,
#   '2010-02-06',
#   5.0),
#  (406171,
#   'sarasota s supreme smoky scalloped potatoes   ham',
#   1275177,
#   '2010-04-07',
#   5.0),
#  (406171,
#   'sarasota s supreme smoky scalloped potatoes   ham',
#   269521,
#   '2011-05-10',
#   5.0),
#  (406171,
#   'sarasota s supreme smoky scalloped potatoes   ham',
#   28087,
#   '2011-12-31',
#   5.0),
#  (406171,
#   'sarasota s supreme smoky scalloped potatoes   ham',
#   560491,
#   '2012-02-26',
#   5.0),
#  (402245, 'wheaties cookies', 2001147313, '2016-08-29', 5.0),
#  (11967, 'italian pot roast', 53932, '2006-02-11', 5.0),
#  (98922, 'tomato basil salad', 58104, '2005-08-29', 5.0),
#  (98922, 'tomato basil salad', 209747, '2005-09-06', 5.0),
#  (107573, 'french herb bread', 138376, '2005-04-01', 5.0),
#  (327032, 'giant chocolate chip cookie cake', 1072593, '2011-04-25', 5.0),
#  (327032, 'giant chocolate chip cookie cake', 428060, '2011-07-19', 4.0),
#  (327032, 'giant chocolate chip cookie cake', 2000430194, '2017-02-16', 0.0),
#  (377531, 'diabetic applesauce brownies', 2657055, '2013-01-25', 4.0),
#  (343949, 'pot roast  crock pot', 251917, '2009-02-27', 5.0),
#  (26790, 'pecan pralines', 37691, '2003-01-20', 1.0),
#  (138783,
#   'bread salad with watermelon  feta  and red onion',
#   121690,
#   '2007-06-29',
#   5.0),
#  (138783,
#   'bread salad with watermelon  feta  and red onion',
#   465056,
#   '2007-07-18',
#   3.0),
#  (239666, 'italian vienna bread 2007', 160974, '2007-08-09', 5.0),
#  (239666, 'italian vienna bread 2007', 130819, '2007-08-17', 5.0),
#  (239666, 'italian vienna bread 2007', 1858347, '2014-01-27', 0.0),
#  (239666, 'italian vienna bread 2007', 1803060179, '2015-07-22', 1.0),
#  (330830, 'pasta fagioli', 138799, '2008-11-01', 5.0),
#  (399786, 'sloppy joe s on cornbread', 44393, '2010-01-08', 4.0),
#  (484603, 'roman kebabs', 498271, '2013-02-27', 5.0),
#  (311436, 'fish in orange creme', 870840, '2008-07-23', 4.0),
#  (378143,
#   'autumn sausage casserole  in the crock pot',
#   220433,
#   '2009-09-22',
#   5.0),
#  (378143,
#   'autumn sausage casserole  in the crock pot',
#   341170,
#   '2009-10-07',
#   3.0),
#  (378143,
#   'autumn sausage casserole  in the crock pot',
#   518581,
#   '2009-10-17',
#   4.0),
#  (232086, 'golden chocolate chip muffins', 244913, '2007-09-23', 3.0),
#  (232086, 'golden chocolate chip muffins', 705251, '2008-07-18', 3.0),
#  (232088, 'potato chip chocolate chip cookies', 136997, '2009-06-17', 5.0),
#  (232088, 'potato chip chocolate chip cookies', 831774, '2010-05-15', 5.0),
#  (232088, 'potato chip chocolate chip cookies', 2198343, '2014-12-03', 4.0),
#  (232092, 'oven roasted tomatoes', 54678, '2008-03-12', 5.0),
#  (232092, 'oven roasted tomatoes', 284897, '2008-03-13', 5.0),
#  (232092, 'oven roasted tomatoes', 587675, '2010-08-04', 5.0),
#  (149492, 'dalmation bark', 227039, '2005-12-28', 0.0),
#  (149492, 'dalmation bark', 257653, '2008-07-14', 5.0),
#  (337696, 'cranberry edamame wild rice salad', 902736, '2009-02-05', 4.0),
#  (337696, 'cranberry edamame wild rice salad', 494867, '2011-10-16', 5.0),
#  (94442, 'rice  and corn with chipotle peppers', 1227563, '2012-08-28', 5.0),
#  (94442, 'rice  and corn with chipotle peppers', 118840, '2005-06-09', 5.0),
#  (94442, 'rice  and corn with chipotle peppers', 305531, '2008-06-27', 5.0),
#  (94442, 'rice  and corn with chipotle peppers', 527886, '2008-07-01', 4.0),
#  (94442, 'rice  and corn with chipotle peppers', 677508, '2008-07-10', 5.0),
#  (94442, 'rice  and corn with chipotle peppers', 213139, '2009-08-03', 5.0),
#  (129621, 'baked potato soup', 29782, '2008-11-07', 5.0),
#  (218898, 'nana s chicken wings', 392230, '2007-04-12', 5.0),
#  (218898, 'nana s chicken wings', 366373, '2007-04-29', 5.0),
#  (218898, 'nana s chicken wings', 165326, '2007-07-17', 5.0),
#  (218898, 'nana s chicken wings', 394077, '2008-05-08', 5.0),
#  (218898, 'nana s chicken wings', 226863, '2012-09-09', 5.0),
#  (275688, 'pineapple chicken', 1339782, '2009-07-30', 5.0),
#  (330865, 'indian tea', 498271, '2009-01-11', 5.0),
#  (330865, 'indian tea', 128473, '2012-08-19', 5.0),
#  (330865, 'indian tea', 107135, '2012-08-28', 5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   2002016619,
#   '2018-03-02',
#   5.0),
#  (93133, 'pesto dip', 126272, '2004-06-21', 5.0),
#  (93133, 'pesto dip', 425154, '2007-10-22', 5.0),
#  (98536, 'crumble topped zucchini walnut muffins', 1301067, '2011-06-13', 4.0),
#  (362066, 'pork chop and stuffing bake', 212497, '2011-08-02', 5.0),
#  (362066, 'pork chop and stuffing bake', 424680, '2012-01-26', 5.0),
#  (59138, 'baked apples stuffed with halvah', 38218, '2003-09-16', 5.0),
#  (234964,
#   'trinidad black cake  a hilarious  tasty  rummy  lump of a cake',
#   19129,
#   '2007-12-22',
#   5.0),
#  (257171,
#   'chicken fricassee with lemon mustard sauce',
#   452940,
#   '2008-03-24',
#   5.0),
#  (257171,
#   'chicken fricassee with lemon mustard sauce',
#   713116,
#   '2008-04-17',
#   5.0),
#  (86006, 'twice baked french fries', 415204, '2007-01-30', 4.0),
#  (176690, 'our favorite buttermilk pancakes', 424680, '2008-10-02', 5.0),
#  (176690, 'our favorite buttermilk pancakes', 286566, '2011-06-05', 4.0),
#  (17099, 'easy cocoa fudge', 6357, '2003-04-01', 5.0),
#  (146038, 'cheesy chicken macaroni bake', 507160, '2007-10-08', 4.0),
#  (214844,
#   'pasta with portabella mushrooms in mustard sauce',
#   93446,
#   '2007-07-09',
#   5.0),
#  (347153, 'snowy night short rib stew', 178427, '2009-11-12', 5.0),
#  (364211, 'simple zesty yogurt cucumber salad', 696423, '2010-04-08', 4.0),
#  (92798, 'squashed cabbage', 75218, '2004-06-22', 5.0),
#  (92798, 'squashed cabbage', 131126, '2004-06-23', 5.0),
#  (92798, 'squashed cabbage', 123865, '2004-06-24', 5.0),
#  (92798, 'squashed cabbage', 21752, '2004-06-28', 5.0),
#  (92798, 'squashed cabbage', 29418, '2005-10-18', 5.0),
#  (112973, 'basic mashed potatoes', 53959, '2006-01-28', 5.0),
#  (112973, 'basic mashed potatoes', 57042, '2007-03-07', 5.0),
#  (157923, 'seven layer rigatoni', 329251, '2006-08-27', 4.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   252816,
#   '2007-05-24',
#   5.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   229524,
#   '2007-05-26',
#   5.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   32772,
#   '2007-07-07',
#   5.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   371738,
#   '2007-10-07',
#   1.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   245301,
#   '2008-02-10',
#   4.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   546021,
#   '2008-03-14',
#   5.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   136447,
#   '2009-03-17',
#   4.0),
#  (190466,
#   'italian pork loin for the slow cooker  crock pot',
#   173030,
#   '2010-10-05',
#   5.0),
#  (334869, 'asparagus frittata', 286566, '2008-11-11', 5.0),
#  (111937, 'foot stomping chicken chili', 1193707, '2011-06-26', 5.0),
#  (18139, 'sausage and potato quick fix', 18660, '2006-07-26', 5.0),
#  (48665, 'lacy wafers', 498271, '2007-12-10', 4.0),
#  (513016, 'easy chocolate chip cookie bars', 2597942, '2014-05-11', 4.0),
#  (17083, 'yummy banana bread', 23302, '2002-01-17', 4.0),
#  (17083, 'yummy banana bread', 27783, '2002-01-21', 5.0),
#  (17083, 'yummy banana bread', 8688, '2002-03-05', 5.0),
#  (17083, 'yummy banana bread', 28671, '2002-03-26', 5.0),
#  (17083, 'yummy banana bread', 34687, '2002-03-26', 5.0),
#  (17083, 'yummy banana bread', 29920, '2002-04-02', 4.0),
#  (17083, 'yummy banana bread', 36780, '2002-04-08', 0.0),
#  (17083, 'yummy banana bread', 26723, '2002-05-14', 5.0),
#  (17083, 'yummy banana bread', 33823, '2002-05-27', 5.0),
#  (17083, 'yummy banana bread', 49304, '2002-09-05', 5.0),
#  (17083, 'yummy banana bread', 38647, '2002-09-09', 5.0),
#  (17083, 'yummy banana bread', 23701, '2002-12-02', 5.0),
#  (17083, 'yummy banana bread', 65166, '2002-12-29', 5.0),
#  (17083, 'yummy banana bread', 10701, '2003-01-09', 5.0),
#  (17083, 'yummy banana bread', 28628, '2003-01-20', 5.0),
#  (17083, 'yummy banana bread', 70907, '2003-03-03', 5.0),
#  (17083, 'yummy banana bread', 66899, '2003-03-05', 5.0),
#  (17083, 'yummy banana bread', 123294, '2004-01-24', 5.0),
#  (17083, 'yummy banana bread', 68938, '2004-03-28', 5.0),
#  (17083, 'yummy banana bread', 25455, '2006-07-13', 3.0),
#  (17083, 'yummy banana bread', 320843, '2006-07-20', 5.0),
#  (17083, 'yummy banana bread', 230258, '2006-12-26', 5.0),
#  (17083, 'yummy banana bread', 31550, '2007-04-22', 5.0),
#  (17083, 'yummy banana bread', 598148, '2007-09-26', 5.0),
#  (17083, 'yummy banana bread', 192972, '2007-11-12', 5.0),
#  (17083, 'yummy banana bread', 130663, '2008-01-30', 5.0),
#  (17083, 'yummy banana bread', 105780, '2008-02-01', 5.0),
#  (17083, 'yummy banana bread', 804329, '2008-06-01', 4.0),
#  (17083, 'yummy banana bread', 441981, '2008-10-24', 5.0),
#  (17083, 'yummy banana bread', 71772, '2008-11-30', 5.0),
#  (17083, 'yummy banana bread', 165064, '2009-07-10', 0.0),
#  (17083, 'yummy banana bread', 278639, '2009-08-29', 5.0),
#  (17083, 'yummy banana bread', 720912, '2009-09-20', 5.0),
#  (17083, 'yummy banana bread', 1634772, '2010-06-16', 5.0),
#  (17083, 'yummy banana bread', 141756, '2010-09-29', 5.0),
#  (17083, 'yummy banana bread', 2000779473, '2015-12-27', 5.0),
#  (17083, 'yummy banana bread', 36344, '2018-02-02', 5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   319738,
#   '2006-08-08',
#   4.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   39835,
#   '2006-08-26',
#   4.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   345110,
#   '2006-11-04',
#   1.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   455010,
#   '2007-06-14',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   359899,
#   '2007-11-14',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   348247,
#   '2007-11-19',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   283773,
#   '2008-02-14',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   528137,
#   '2008-02-23',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   731905,
#   '2008-03-10',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   29450,
#   '2008-06-15',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   386380,
#   '2008-11-12',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   180406,
#   '2009-02-17',
#   4.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   496803,
#   '2009-03-17',
#   4.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   306797,
#   '2009-05-19',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   904483,
#   '2009-05-31',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   274139,
#   '2009-06-14',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   657191,
#   '2009-06-20',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   1332481,
#   '2009-07-22',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   1168148,
#   '2009-08-01',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   870390,
#   '2009-11-17',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   107583,
#   '2010-08-15',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   576273,
#   '2013-04-05',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   567380,
#   '2013-06-26',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   2000251469,
#   '2015-06-06',
#   0.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   57256,
#   '2015-10-10',
#   5.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   202026,
#   '2016-10-16',
#   0.0),
#  (171002,
#   'grilled bourbon marinated pork chops or pork tenderloins',
#   226863,
#   '2018-03-25',
#   5.0),
#  (436329, 'finish lace cookies', 186855, '2012-05-10', 5.0),
#  (28225, 'cola quick cake', 356127, '2006-10-13', 5.0),
#  (28225, 'cola quick cake', 1042494, '2015-02-04', 5.0),
#  (69243, 'smoked paprika chicken breast', 50141, '2005-04-05', 4.0),
#  (333243, 'caramel ring a round', 572571, '2010-08-25', 4.0),
#  (7379, 'curried oysters with banana salsa', 2625, '2001-05-24', 0.0),
#  (345181, 'shrimp and mirliton dressing', 1378827, '2009-11-23', 0.0),
#  (345181, 'shrimp and mirliton dressing', 2535494, '2012-11-30', 0.0),
#  (69243, 'smoked paprika chicken breast', 52448, '2003-09-10', 5.0),
#  (69243, 'smoked paprika chicken breast', 71772, '2006-11-06', 5.0),
#  (69243, 'smoked paprika chicken breast', 432201, '2007-03-06', 5.0),
#  (69243, 'smoked paprika chicken breast', 13796, '2007-03-11', 5.0),
#  (69243, 'smoked paprika chicken breast', 192264, '2007-04-25', 5.0),
#  (69243, 'smoked paprika chicken breast', 313487, '2008-02-21', 5.0),
#  (69243, 'smoked paprika chicken breast', 797486, '2008-07-29', 4.0),
#  (69243, 'smoked paprika chicken breast', 217615, '2009-01-05', 5.0),
#  (69243, 'smoked paprika chicken breast', 204116, '2009-02-03', 5.0),
#  (69243, 'smoked paprika chicken breast', 55655, '2009-06-29', 5.0),
#  (69243, 'smoked paprika chicken breast', 1163252, '2010-03-28', 5.0),
#  (69243, 'smoked paprika chicken breast', 904655, '2010-05-07', 5.0),
#  (69243, 'smoked paprika chicken breast', 844554, '2010-10-30', 5.0),
#  (69243, 'smoked paprika chicken breast', 50969, '2011-02-03', 4.0),
#  (69243, 'smoked paprika chicken breast', 571308, '2011-02-09', 5.0),
#  (69243, 'smoked paprika chicken breast', 550949, '2011-06-24', 4.0),
#  (69243, 'smoked paprika chicken breast', 2479166, '2014-01-09', 0.0),
#  (69243, 'smoked paprika chicken breast', 165933, '2014-06-01', 5.0),
#  (101781, 'pammy s awesome easy gravy', 4470, '2004-10-14', 5.0),
#  (101781, 'pammy s awesome easy gravy', 168257, '2004-10-18', 5.0),
#  (101781, 'pammy s awesome easy gravy', 160974, '2007-02-28', 5.0),
#  (101781, 'pammy s awesome easy gravy', 161282, '2012-09-20', 5.0),
#  (152660,
#   'clay pot chicken with garlic carrots and potatoes',
#   249519,
#   '2006-11-07',
#   5.0),
#  (152660,
#   'clay pot chicken with garlic carrots and potatoes',
#   537524,
#   '2007-07-15',
#   5.0),
#  (152660,
#   'clay pot chicken with garlic carrots and potatoes',
#   2855381,
#   '2013-06-08',
#   5.0),
#  (152660,
#   'clay pot chicken with garlic carrots and potatoes',
#   2000486641,
#   '2016-01-02',
#   0.0),
#  (123506, 'irish breakfast fruit crisp', 243224, '2007-03-17', 5.0),
#  (335889, 'velveeta dirty dip', 77458, '2008-12-31', 4.0),
#  (346687, 'apple berry pomegranate freezer jam', 1938147, '2011-06-26', 5.0),
#  (82226, 'vanilla milk', 134011, '2005-10-21', 5.0),
#  (230965, 'cucumber salad', 131126, '2008-04-13', 5.0),
#  (230965, 'cucumber salad', 337963, '2008-05-28', 3.0),
#  (230965, 'cucumber salad', 463202, '2008-05-30', 3.0),
#  (230965, 'cucumber salad', 171790, '2008-06-02', 4.0),
#  (29626, 'teriyaki glazed salmon patties', 37449, '2007-12-10', 4.0),
#  (34903, 'creamy apricot chicken', 463202, '2007-04-24', 4.0),
#  (343902, 'breakfast burrito', 601528, '2009-02-28', 4.0),
#  (330555, 'rich chicken broth', 201581, '2009-11-08', 5.0),
#  (415441,
#   'roasted new potatoes  middle eastern style',
#   28087,
#   '2010-06-09',
#   5.0),
#  (415441,
#   'roasted new potatoes  middle eastern style',
#   780172,
#   '2010-06-11',
#   5.0),
#  (415441,
#   'roasted new potatoes  middle eastern style',
#   226863,
#   '2010-06-12',
#   5.0),
#  (427667,
#   'piselli al prosciutto  sweet peas with prosciutto',
#   305531,
#   '2016-10-21',
#   5.0),
#  (232059, 'momma simo s popcorn', 461834, '2007-06-12', 5.0),
#  (232057, 'mexican macaroni and beef', 54572, '2007-10-31', 4.0),
#  (232059, 'momma simo s popcorn', 37449, '2007-06-10', 5.0),
#  (232059, 'momma simo s popcorn', 329769, '2007-06-11', 5.0),
#  (232059, 'momma simo s popcorn', 275207, '2007-09-08', 4.0),
#  (232059, 'momma simo s popcorn', 199198, '2007-12-11', 5.0),
#  (232059, 'momma simo s popcorn', 65502, '2009-07-06', 5.0),
#  (232059, 'momma simo s popcorn', 1118667, '2010-01-10', 5.0),
#  (86712, 'white cheddar potato gratin', 120121, '2004-03-17', 5.0),
#  (86712, 'white cheddar potato gratin', 132407, '2004-03-22', 4.0),
#  (86712, 'white cheddar potato gratin', 321999, '2010-04-05', 5.0),
#  (86712, 'white cheddar potato gratin', 2001235230, '2016-11-06', 5.0),
#  (156208, 'clams oreganata', 241696, '2008-12-24', 5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2001438763,
#   '2017-06-22',
#   0.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   1399224,
#   '2009-09-29',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   1366254,
#   '2009-10-01',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   589394,
#   '2010-01-08',
#   4.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   1787795,
#   '2011-01-06',
#   0.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   1852777,
#   '2011-05-02',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2040049,
#   '2011-10-21',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2388124,
#   '2012-09-03',
#   2.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2002133271,
#   '2018-04-28',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   732723,
#   '2013-03-29',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2000241679,
#   '2015-06-01',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2000543713,
#   '2015-12-31',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2001269687,
#   '2016-11-25',
#   4.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2001320410,
#   '2016-12-25',
#   5.0),
#  (392181,
#   'the real  black tie mousse cake by olive garden',
#   2002205107,
#   '2018-07-02',
#   3.0),
#  (4699, 'english christmas pudding ii', 68524, '2003-01-19', 5.0),
#  (4699, 'english christmas pudding ii', 96806, '2004-12-30', 4.0),
#  (234424, 'poulet rti   roast chicken', 452940, '2008-03-18', 4.0),
#  (234424, 'poulet rti   roast chicken', 197023, '2009-04-18', 5.0),
#  (234424, 'poulet rti   roast chicken', 1155210, '2009-05-28', 5.0),
#  (234424, 'poulet rti   roast chicken', 463202, '2009-05-29', 4.0),
#  (234424, 'poulet rti   roast chicken', 369715, '2010-11-03', 5.0),
#  (234424, 'poulet rti   roast chicken', 80353, '2011-06-21', 5.0),
#  (234424, 'poulet rti   roast chicken', 280271, '2011-10-02', 5.0),
#  (234424, 'poulet rti   roast chicken', 482376, '2012-07-26', 0.0),
#  (234424, 'poulet rti   roast chicken', 226863, '2012-07-29', 5.0),
#  (234424, 'poulet rti   roast chicken', 502302, '2013-01-18', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 67656, '2007-10-21', 4.0),
#  (258345, 'low fat   mc donald s  french fries', 107583, '2007-10-26', 4.0),
#  (258345, 'low fat   mc donald s  french fries', 484390, '2007-11-01', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 444607, '2007-12-25', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 409333, '2008-01-04', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 469831, '2008-01-16', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 337449, '2008-03-25', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 24386, '2008-05-02', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 337963, '2008-05-14', 3.0),
#  (258345, 'low fat   mc donald s  french fries', 294000, '2008-05-31', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 804851, '2008-06-14', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 29782, '2008-07-29', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 248023, '2008-08-09', 4.0),
#  (258345, 'low fat   mc donald s  french fries', 569675, '2009-04-26', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 116869, '2009-09-08', 0.0),
#  (258345, 'low fat   mc donald s  french fries', 930470, '2009-10-07', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 201581, '2010-08-13', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 844554, '2010-08-28', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 127933, '2010-09-10', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 1657681, '2010-10-31', 5.0),
#  (350006, 'crock pot buffalo chicken chili', 949002, '2009-02-26', 4.0),
#  (258345, 'low fat   mc donald s  french fries', 1511723, '2011-07-03', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 424680, '2011-07-10', 5.0),
#  (258345, 'low fat   mc donald s  french fries', 1365025, '2011-07-18', 4.0),
#  (258345, 'low fat   mc donald s  french fries', 560491, '2011-08-12', 4.0),
#  (258345, 'low fat   mc donald s  french fries', 1002265, '2012-01-23', 5.0),
#  (258345,
#   'low fat   mc donald s  french fries',
#   1803005318,
#   '2016-10-16',
#   3.0),
#  (350006, 'crock pot buffalo chicken chili', 592141, '2009-01-27', 5.0),
#  (350006, 'crock pot buffalo chicken chili', 860079, '2009-02-10', 5.0),
#  (350006, 'crock pot buffalo chicken chili', 67656, '2009-04-17', 5.0),
#  (350006, 'crock pot buffalo chicken chili', 259154, '2009-09-05', 3.0),
#  (350006, 'crock pot buffalo chicken chili', 485773, '2010-12-09', 5.0),
#  (350006, 'crock pot buffalo chicken chili', 407007, '2013-11-26', 5.0),
#  (49474, 'turkey cranberry quesadillas', 2000498330, '2018-12-04', 5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   37305,
#   '2007-12-31',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   157425,
#   '2008-01-18',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   204024,
#   '2008-02-12',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   102058,
#   '2008-02-23',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   461834,
#   '2008-03-06',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   369363,
#   '2008-03-31',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   124416,
#   '2008-04-14',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   578914,
#   '2008-05-06',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   602448,
#   '2008-05-27',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   197023,
#   '2008-07-25',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   111678,
#   '2008-07-29',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   35526,
#   '2008-08-07',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   259150,
#   '2008-08-29',
#   3.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   709498,
#   '2008-09-14',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   486648,
#   '2008-11-15',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   68526,
#   '2009-02-25',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   474322,
#   '2009-05-28',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   205783,
#   '2009-06-05',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   203111,
#   '2009-07-25',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   118007,
#   '2009-09-12',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   328467,
#   '2010-03-31',
#   4.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   880889,
#   '2010-06-25',
#   3.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   1684658,
#   '2010-09-14',
#   0.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   449102,
#   '2010-09-28',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   1730315,
#   '2010-11-14',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   482242,
#   '2011-04-03',
#   0.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   418017,
#   '2011-10-12',
#   3.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   1365025,
#   '2012-11-05',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   2044948,
#   '2012-12-08',
#   4.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   318262,
#   '2014-08-22',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   226753,
#   '2014-12-26',
#   5.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   2000293071,
#   '2015-06-24',
#   1.0),
#  (273976,
#   'the simplest tomato sauce ever   marcella hazan',
#   2000398101,
#   '2015-08-11',
#   5.0),
#  (209718, 'gluten free pie crust', 474170, '2007-03-30', 5.0),
#  (209718, 'gluten free pie crust', 802773, '2010-11-28', 4.0),
#  (350602, 'shepherd s pie with zucchini', 599450, '2009-10-03', 5.0),
#  (401824, 'maple syrup baked sweet potato', 1615854, '2010-10-11', 5.0),
#  (401824, 'maple syrup baked sweet potato', 407338, '2010-03-05', 5.0),
#  (401824, 'maple syrup baked sweet potato', 133174, '2010-08-08', 0.0),
#  (145465,
#   'crock pot can it really be so easy roast beef',
#   57437,
#   '2007-10-04',
#   5.0),
#  (145465,
#   'crock pot can it really be so easy roast beef',
#   369715,
#   '2010-04-16',
#   5.0),
#  (315033, 'danielle s spinach squares', 88099, '2012-03-31', 5.0),
#  (315033, 'danielle s spinach squares', 131126, '2012-04-15', 5.0),
#  (80189, 'spicy chicken with tangy yoghurt', 900992, '2009-02-20', 1.0),
#  (199138, 'creamy fast rice', 369715, '2007-10-05', 2.0),
#  (199138, 'creamy fast rice', 86512, '2007-10-06', 2.0),
#  (279221, 'beans and franks bake oamc', 910737, '2008-08-03', 5.0),
#  (279221, 'beans and franks bake oamc', 978517, '2008-11-08', 5.0),
#  (279221, 'beans and franks bake oamc', 1582575, '2012-01-23', 5.0),
#  (37413, 'beef patties in onion gravy', 968335, '2012-01-23', 5.0),
#  (182259, 'cream of parisian vegetable soup', 327600, '2007-01-12', 4.0),
#  (182259, 'cream of parisian vegetable soup', 445602, '2007-11-06', 5.0),
#  (182259, 'cream of parisian vegetable soup', 386585, '2012-01-18', 4.0),
#  (325995, 'marmalade meatballs', 2000498330, '2016-02-23', 5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   160974,
#   '2005-08-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   209441,
#   '2005-08-28',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   133174,
#   '2006-03-27',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   129652,
#   '2006-04-10',
#   4.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   168462,
#   '2006-05-18',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   50151,
#   '2006-05-30',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   33159,
#   '2006-07-08',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   269891,
#   '2006-10-04',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   241140,
#   '2007-01-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   260911,
#   '2007-02-20',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   49542,
#   '2007-03-24',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   67961,
#   '2007-03-25',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   314825,
#   '2007-04-17',
#   4.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   497609,
#   '2007-05-09',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   141293,
#   '2007-06-07',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   57222,
#   '2007-07-04',
#   4.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   195750,
#   '2007-08-02',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   247362,
#   '2007-09-08',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   57101,
#   '2007-09-25',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   91392,
#   '2007-10-01',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   60992,
#   '2007-10-13',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   551470,
#   '2007-12-05',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   169430,
#   '2008-02-26',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   165206,
#   '2008-03-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   354675,
#   '2008-03-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   493835,
#   '2008-05-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   382071,
#   '2008-05-11',
#   4.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   848785,
#   '2008-05-30',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   226066,
#   '2008-07-07',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   546012,
#   '2008-07-15',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   441981,
#   '2008-07-22',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   919613,
#   '2008-08-11',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   604139,
#   '2008-09-28',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   139930,
#   '2008-12-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   485335,
#   '2009-01-13',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   394077,
#   '2009-01-30',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   514022,
#   '2009-02-05',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   457907,
#   '2009-04-21',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   444132,
#   '2009-06-01',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   298981,
#   '2014-01-31',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   470351,
#   '2009-08-23',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   531310,
#   '2009-08-25',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1159243,
#   '2009-10-30',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   755020,
#   '2009-12-07',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   457321,
#   '2010-01-02',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   111291,
#   '2010-01-05',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1627976,
#   '2010-06-05',
#   0.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1275428,
#   '2010-06-18',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   48196,
#   '2010-12-03',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   561908,
#   '2011-04-27',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   50711,
#   '2011-11-13',
#   0.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   2536375,
#   '2012-12-07',
#   4.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   363055,
#   '2013-06-12',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   666681,
#   '2014-02-15',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1802647601,
#   '2014-04-06',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1547166,
#   '2014-05-15',
#   4.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1179225,
#   '2014-06-22',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   32772,
#   '2014-09-01',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   651350,
#   '2014-09-22',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1803384077,
#   '2014-11-22',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   1803212001,
#   '2015-08-07',
#   5.0),
#  (119804,
#   'kittencal s banana cinnamon snack cake or muffins  low fat',
#   2001495244,
#   '2017-04-18',
#   5.0),
#  (159553,
#   'steve s wonderful and relatively uncomplicated pico de gallo',
#   303700,
#   '2006-10-28',
#   5.0),
#  (345232, 'perfect corn dogs', 573772, '2012-02-17', 5.0),
#  (37413, 'beef patties in onion gravy', 350750, '2012-04-19', 5.0),
#  (55822, 'kentucky blueberry coffee cake', 50969, '2003-08-16', 5.0),
#  (55822, 'kentucky blueberry coffee cake', 93006, '2004-06-28', 5.0),
#  (55822, 'kentucky blueberry coffee cake', 186487, '2005-07-15', 5.0),
#  (55822, 'kentucky blueberry coffee cake', 237655, '2006-05-03', 4.0),
#  (55822, 'kentucky blueberry coffee cake', 1331998, '2009-08-25', 5.0),
#  (55822, 'kentucky blueberry coffee cake', 214469, '2010-03-23', 5.0),
#  (112656, 'zippy cheese crostini', 153188, '2005-05-30', 4.0),
#  (68677, 'rosemary chicken wings', 37449, '2005-02-14', 5.0),
#  (28140, 'hhhhhot crab dip', 37106, '2002-07-10', 5.0),
#  (28140, 'hhhhhot crab dip', 31232, '2002-09-02', 5.0),
#  (192524, 'southwest chicken pasta', 602074, '2007-10-03', 5.0),
#  (192524, 'southwest chicken pasta', 96177, '2007-12-22', 5.0),
#  (395571, 'tuscan bruschetta dip', 242729, '2010-01-08', 5.0),
#  (395571, 'tuscan bruschetta dip', 573325, '2010-05-27', 5.0),
#  (395571, 'tuscan bruschetta dip', 383346, '2010-07-24', 5.0),
#  (33145, 'long island sunset', 49360, '2002-07-17', 5.0),
#  (33145, 'long island sunset', 60221, '2003-05-27', 5.0),
#  (121245, 'orange melon smoothies', 128473, '2009-07-09', 4.0),
#  (121245, 'orange melon smoothies', 424680, '2011-06-20', 5.0),
#  (350905, 'spinach dish', 4470, '2009-03-29', 5.0),
#  (350905, 'spinach dish', 653438, '2013-04-11', 5.0),
#  (224096, 'schmierkaese  cheese spread', 139381, '2007-04-24', 0.0),
#  (224096, 'schmierkaese  cheese spread', 422893, '2008-05-27', 4.0),
#  (224096, 'schmierkaese  cheese spread', 37449, '2008-05-30', 4.0),
#  (224096, 'schmierkaese  cheese spread', 337668, '2010-05-24', 5.0),
#  (224096, 'schmierkaese  cheese spread', 179133, '2012-03-18', 5.0),
#  (515167,
#   'simply irresistible tropical potato salad  sp5',
#   1802640317,
#   '2014-04-03',
#   5.0),
#  (515167,
#   'simply irresistible tropical potato salad  sp5',
#   1802640322,
#   '2014-04-03',
#   5.0),
#  (396305, 'fairy bread', 242729, '2009-10-26', 5.0),
#  (396305, 'fairy bread', 1375473, '2009-10-27', 5.0),
#  (396305, 'fairy bread', 1417792, '2009-12-19', 5.0),
#  (515167,
#   'simply irresistible tropical potato salad  sp5',
#   1802640735,
#   '2014-04-03',
#   5.0),
#  (150831, 'frozen ginger cream', 993604, '2011-03-12', 5.0),
#  (11040, 'asparagus  oven roasted', 18391, '2002-03-22', 5.0),
#  (11040, 'asparagus  oven roasted', 20114, '2002-04-02', 5.0),
#  (11040, 'asparagus  oven roasted', 27783, '2002-04-14', 4.0),
#  (11040, 'asparagus  oven roasted', 3288, '2002-04-20', 5.0),
#  (11040, 'asparagus  oven roasted', 34122, '2002-05-02', 5.0),
#  (11040, 'asparagus  oven roasted', 35281, '2002-05-07', 4.0),
#  (11040, 'asparagus  oven roasted', 23728, '2002-05-08', 5.0),
#  (11040, 'asparagus  oven roasted', 31232, '2002-05-15', 5.0),
# ...
#   124268,
#   '2009-10-06',
#   5.0),
#  (155402,
#   'easy cheddar spinach and  mushroom pie with puff pastry crust',
#   180406,
#   '2009-12-07',
#   5.0),
#  (155402,
#   'easy cheddar spinach and  mushroom pie with puff pastry crust',
#   391624,
#   '2010-01-23',
#   5.0),
#  (155402,
#   'easy cheddar spinach and  mushroom pie with puff pastry crust',
#   1436160,
#   '2011-01-25',
#   5.0),
#  (179478, 'apple nut bread', 53123, '2006-12-18', 5.0),
#  (179478, 'apple nut bread', 1663041, '2017-10-18', 5.0),
#  (179478, 'apple nut bread', 1802044924, '2018-08-23', 5.0),
#  (179478, 'apple nut bread', 2002312290, '2018-10-26', 5.0),
#  (281046, 'uncle vinnie s spaghetti sauce', 344231, '2008-05-04', 4.0),
#  (456076, 'swiss potato gratin', 461834, '2011-11-09', 5.0),
#  (485268, 'irish oatmeal with pears and maple', 486725, '2014-03-13', 4.0),
#  (485268, 'irish oatmeal with pears and maple', 107135, '2012-08-20', 5.0),
#  (485268, 'irish oatmeal with pears and maple', 381180, '2013-02-14', 5.0),
#  (114103, 'crock pot pork and beans', 109938, '2006-03-11', 5.0),
#  (115753, 'spinach crab stuffed chicken', 146783, '2008-02-01', 5.0),
#  (115753, 'spinach crab stuffed chicken', 377161, '2009-03-16', 5.0),
#  (74299, 'lime mousse brownie dessert', 93446, '2004-09-18', 5.0),
#  (74299, 'lime mousse brownie dessert', 82648, '2004-09-29', 5.0),
#  (114103, 'crock pot pork and beans', 130819, '2009-01-26', 5.0),
#  (114103, 'crock pot pork and beans', 2293361, '2012-09-05', 5.0),
#  (658, 'dried fruit roll ups', 247241, '2006-01-05', 4.0),
#  (23380, 'chicken and mushrooms with cheese', 36707, '2002-04-01', 4.0),
#  (23380, 'chicken and mushrooms with cheese', 9869, '2002-04-28', 4.0),
#  (23380, 'chicken and mushrooms with cheese', 68180, '2003-03-08', 5.0),
#  (23380, 'chicken and mushrooms with cheese', 52607, '2003-03-09', 5.0),
#  (23380, 'chicken and mushrooms with cheese', 62191, '2003-03-10', 4.0),
#  (23380, 'chicken and mushrooms with cheese', 67067, '2003-03-12', 4.0),
#  (23380, 'chicken and mushrooms with cheese', 43292, '2003-03-15', 5.0),
#  (23380, 'chicken and mushrooms with cheese', 56498, '2003-04-04', 4.0),
#  (22667,
#   'lemon chicken pasta with broccoli   peppers',
#   299463,
#   '2007-12-09',
#   4.0),
#  (42959, 'easy gloucester bay cheddar biscuits', 153401, '2006-02-07', 4.0),
#  (21842, 'homestyle macaroni and cheese bake', 4740, '2007-12-24', 5.0),
#  (21842, 'homestyle macaroni and cheese bake', 910477, '2010-02-12', 5.0),
#  (635, 'dill bread', 165845, '2004-11-10', 5.0),
#  (635, 'dill bread', 1013122, '2008-11-03', 5.0),
#  (635, 'dill bread', 1578011, '2010-03-15', 5.0),
#  (382460, 'hannah s butter mints', 407283, '2009-12-23', 2.0),
#  (323576, 'apple and celery salad', 199848, '2008-09-30', 5.0),
#  (323576, 'apple and celery salad', 135377, '2008-10-02', 5.0),
#  (323576, 'apple and celery salad', 537188, '2008-10-19', 5.0),
#  (323576, 'apple and celery salad', 283390, '2009-02-13', 5.0),
#  (325771, 'dan s baja chicken', 2000812651, '2016-01-10', 5.0),
#  (376557,
#   'cheezy chicken parmesan with zucchini  pasta',
#   324017,
#   '2011-02-28',
#   4.0),
#  (242764, 'middle eastern carrot salad', 47892, '2008-08-07', 5.0),
#  (242764, 'middle eastern carrot salad', 252727, '2010-07-20', 5.0),
#  (311491,
#   'healthy pancakes  really    they re healthy',
#   334010,
#   '2008-08-11',
#   5.0),
#  (365179, 'hearty grilled cheese', 226863, '2009-06-28', 5.0),
#  (365179, 'hearty grilled cheese', 1072593, '2009-10-30', 5.0),
#  (365179, 'hearty grilled cheese', 628076, '2009-11-09', 5.0),
#  (365179, 'hearty grilled cheese', 165623, '2009-11-29', 5.0),
#  (365179, 'hearty grilled cheese', 705251, '2010-01-31', 5.0),
#  (365179, 'hearty grilled cheese', 286566, '2010-04-25', 5.0),
#  (365179, 'hearty grilled cheese', 166642, '2010-06-05', 5.0),
#  (365179, 'hearty grilled cheese', 201581, '2010-08-07', 5.0),
#  (365179, 'hearty grilled cheese', 305531, '2010-12-18', 5.0),
#  (29318, 'homemade self rising flour   substitute', 465829, '2009-03-08', 4.0),
#  (272854, 'easy no fail chocolate fudge', 461834, '2008-05-03', 4.0),
#  (272854, 'easy no fail chocolate fudge', 620763, '2012-12-17', 5.0),
#  (307640, 'green beans with caramelized onions', 211040, '2008-06-08', 5.0),
#  (307640, 'green beans with caramelized onions', 801143, '2008-06-23', 5.0),
#  (307640, 'green beans with caramelized onions', 461834, '2009-07-18', 5.0),
#  (307640, 'green beans with caramelized onions', 679953, '2009-07-25', 5.0),
#  (307640, 'green beans with caramelized onions', 25063, '2009-07-27', 5.0),
#  (307640, 'green beans with caramelized onions', 273846, '2009-10-27', 5.0),
#  (307640, 'green beans with caramelized onions', 844554, '2009-10-27', 5.0),
#  (307640, 'green beans with caramelized onions', 11461, '2009-10-27', 5.0),
#  (307640, 'green beans with caramelized onions', 894377, '2010-04-10', 5.0),
#  (307640, 'green beans with caramelized onions', 383346, '2010-09-21', 5.0),
#  (307640, 'green beans with caramelized onions', 560491, '2010-11-20', 5.0),
#  (307640, 'green beans with caramelized onions', 628076, '2014-03-24', 4.0),
#  (30648, 'grilled stuffed portabellas', 297076, '2008-09-03', 5.0),
#  (30648, 'grilled stuffed portabellas', 673444, '2010-06-21', 5.0),
#  (180274, 'cajun ratatouille', 437246, '2007-02-06', 5.0),
#  (214690, 'mustard cream sauce for corned beef', 201516, '2008-03-17', 5.0),
#  (245510, 'heavenly', 431813, '2007-08-29', 5.0),
#  (245510, 'heavenly', 351811, '2007-09-05', 5.0),
#  (245510, 'heavenly', 8688, '2007-09-24', 5.0),
#  (245510, 'heavenly', 382071, '2007-10-29', 5.0),
#  (245510, 'heavenly', 324390, '2007-10-31', 5.0),
#  (108742, 'leek and thyme soup', 133174, '2005-02-19', 5.0),
#  (108742, 'leek and thyme soup', 24386, '2005-04-19', 4.0),
#  (108742, 'leek and thyme soup', 89831, '2006-07-12', 5.0),
#  (392890, 'salmon seafood and veggie chowder', 401057, '2009-11-20', 5.0),
#  (424244, 'cottage pie', 222478, '2010-06-26', 5.0),
#  (87275, 'phyllis cake  chocolate mousse pie', 137196, '2004-04-11', 0.0),
#  (134829, 'german spaetzle dumplings', 146742, '2007-07-19', 5.0),
#  (209021, 'blueberry pie a la dr weil', 104295, '2009-07-13', 5.0),
#  (230876, 'tomato tofu bisque  weight watchers', 446143, '2007-06-03', 4.0),
#  (230876, 'tomato tofu bisque  weight watchers', 141293, '2007-10-10', 5.0),
#  (230876,
#   'tomato tofu bisque  weight watchers',
#   2001930164,
#   '2018-01-14',
#   0.0),
#  (288932, 'carrot bundt cake with glaze', 1234311, '2009-04-11', 5.0),
#  (288932, 'carrot bundt cake with glaze', 1105991, '2009-05-04', 5.0),
#  (288932, 'carrot bundt cake with glaze', 284904, '2009-05-29', 5.0),
#  (288932, 'carrot bundt cake with glaze', 1331434, '2010-03-21', 5.0),
#  (429882, 'best cocoa brownies', 693345, '2010-07-04', 0.0),
#  (399916,
#   'chocolate crescent rolls  from scratch',
#   1417096,
#   '2010-02-14',
#   4.0),
#  (399916, 'chocolate crescent rolls  from scratch', 560491, '2010-02-18', 3.0),
#  (106873, 'my family pancakes', 24992, '2005-02-02', 5.0),
#  (106873, 'my family pancakes', 213049, '2005-06-24', 5.0),
#  (106873, 'my family pancakes', 59780, '2005-10-08', 5.0),
#  (106873, 'my family pancakes', 292644, '2006-02-12', 5.0),
#  (106873, 'my family pancakes', 146047, '2006-05-13', 5.0),
#  (106873, 'my family pancakes', 280605, '2006-05-28', 5.0),
#  (106873, 'my family pancakes', 156319, '2006-07-04', 0.0),
#  (106873, 'my family pancakes', 213003, '2006-07-08', 5.0),
#  (106873, 'my family pancakes', 176615, '2006-11-22', 5.0),
#  (106873, 'my family pancakes', 391467, '2007-01-17', 4.0),
#  (106873, 'my family pancakes', 463300, '2007-03-10', 5.0),
#  (106873, 'my family pancakes', 443146, '2008-01-25', 5.0),
#  (106873, 'my family pancakes', 259150, '2008-04-13', 5.0),
#  (106873, 'my family pancakes', 394077, '2008-08-02', 4.0),
#  (106873, 'my family pancakes', 152147, '2008-10-07', 5.0),
#  (398156,
#   'butternut squash soup shots with candied bacon',
#   2423064,
#   '2012-09-28',
#   0.0),
#  (500068, 'montana s spinach dip', 1802447792, '2014-02-02', 4.0),
#  (265000, 'slow cooker stuffing', 363055, '2007-11-25', 5.0),
#  (265000, 'slow cooker stuffing', 1739228, '2011-03-03', 5.0),
#  (265000, 'slow cooker stuffing', 35488, '2011-11-25', 2.0),
#  (29318, 'homemade self rising flour   substitute', 678366, '2009-10-21', 5.0),
#  (228157, 'breakfast cinnamon and apple squares', 608900, '2009-06-07', 4.0),
#  (66077, 'mascarpone cheese substitute', 21752, '2003-10-22', 5.0),
#  (66077, 'mascarpone cheese substitute', 52543, '2004-01-03', 5.0),
#  (66077, 'mascarpone cheese substitute', 354540, '2008-04-15', 5.0),
#  (66077, 'mascarpone cheese substitute', 27416, '2008-08-01', 5.0),
#  (66077, 'mascarpone cheese substitute', 504185, '2008-09-06', 5.0),
#  (66077, 'mascarpone cheese substitute', 1119406, '2009-01-09', 5.0),
#  (66077, 'mascarpone cheese substitute', 416758, '2009-01-22', 5.0),
#  (66077, 'mascarpone cheese substitute', 1409514, '2009-10-09', 5.0),
#  (66077, 'mascarpone cheese substitute', 1122161, '2010-02-04', 5.0),
#  (66077, 'mascarpone cheese substitute', 2000371505, '2015-07-29', 3.0),
#  (66077, 'mascarpone cheese substitute', 2000021570, '2015-09-04', 5.0),
#  (66077, 'mascarpone cheese substitute', 2000593981, '2015-10-23', 0.0),
#  (66077, 'mascarpone cheese substitute', 2001813727, '2017-11-21', 0.0),
#  (117577, 'calypso island chicken', 48107, '2009-04-10', 5.0),
#  (18070, 'chile vinegar turnip greens', 37449, '2002-10-31', 5.0),
#  (18070, 'chile vinegar turnip greens', 133174, '2004-08-10', 5.0),
#  (18070, 'chile vinegar turnip greens', 95743, '2005-06-18', 5.0),
#  (18070, 'chile vinegar turnip greens', 6258, '2005-11-08', 5.0),
#  (18070, 'chile vinegar turnip greens', 68460, '2006-01-02', 5.0),
#  (18070, 'chile vinegar turnip greens', 446917, '2007-10-09', 5.0),
#  (18070, 'chile vinegar turnip greens', 341474, '2009-01-19', 5.0),
#  (18070, 'chile vinegar turnip greens', 63306, '2009-01-20', 5.0),
#  (18070, 'chile vinegar turnip greens', 233829, '2009-06-17', 3.0),
#  (18070, 'chile vinegar turnip greens', 355817, '2009-06-18', 1.0),
#  (18070, 'chile vinegar turnip greens', 376986, '2009-06-30', 3.0),
#  (18070, 'chile vinegar turnip greens', 1257339, '2010-06-06', 5.0),
#  (18070, 'chile vinegar turnip greens', 283390, '2010-07-01', 5.0),
#  (18070, 'chile vinegar turnip greens', 380644, '2011-01-11', 5.0),
#  (18070, 'chile vinegar turnip greens', 1462970, '2012-06-18', 2.0),
#  (18070, 'chile vinegar turnip greens', 432411, '2014-01-28', 5.0),
#  (241569, 'soft boiled eggs with pesto', 895132, '2010-09-14', 5.0),
#  (6790, 'white bean soup', 206101, '2006-04-22', 4.0),
#  (6790, 'white bean soup', 79617, '2006-08-07', 5.0),
#  (6790, 'white bean soup', 1085645, '2009-01-01', 5.0),
#  (6790, 'white bean soup', 120976, '2009-04-17', 5.0),
#  (6790, 'white bean soup', 315565, '2012-06-17', 5.0),
#  (6790, 'white bean soup', 286566, '2012-06-27', 5.0),
#  (90663,
#   'my  base for everything  zippy  marinara sauce',
#   353076,
#   '2006-11-07',
#   5.0),
#  (90663,
#   'my  base for everything  zippy  marinara sauce',
#   204705,
#   '2008-01-22',
#   4.0),
#  (90663,
#   'my  base for everything  zippy  marinara sauce',
#   588654,
#   '2008-01-25',
#   4.0),
#  (111928, 'raw apple or pear cake', 1122379, '2010-12-23', 4.0),
#  (65897, 'baked rice pudding', 55594, '2003-07-23', 5.0),
#  (65897, 'baked rice pudding', 156034, '2007-04-13', 4.0),
#  (65897, 'baked rice pudding', 222696, '2007-08-09', 4.0),
#  (65897, 'baked rice pudding', 242396, '2009-02-12', 4.0),
#  (65897, 'baked rice pudding', 94090, '2009-04-17', 5.0),
#  (128288, 'bbq d spice rubbed chicken breast', 867405, '2015-04-17', 4.0),
#  (463789, 'potato broccoli cheese soup', 2668527, '2013-01-31', 5.0),
#  (463789, 'potato broccoli cheese soup', 2712013, '2013-02-26', 5.0),
#  (463789, 'potato broccoli cheese soup', 2141396, '2017-04-04', 4.0),
#  (83685, 'very easy crock pot pot roast', 126198, '2005-05-29', 0.0),
#  (203720, 'x rated rita', 120647, '2007-02-01', 5.0),
#  (203720, 'x rated rita', 196198, '2011-12-10', 5.0),
#  (293914, 'trego family manhattan clam chowder', 424680, '2008-04-10', 4.0),
#  (63437, 'wasp s nest cake', 233627, '2010-08-08', 5.0),
#  (99261, 'sauerkraut from the naschmarkt', 28636, '2006-05-07', 5.0),
#  (301413, 'perfect whole wheat bread', 62562, '2008-06-18', 5.0),
#  (348783, 'tex mex carnitas', 424680, '2009-05-18', 5.0),
#  (348783, 'tex mex carnitas', 23119, '2009-07-14', 5.0),
#  (348783, 'tex mex carnitas', 231057, '2011-04-20', 5.0),
#  (348783, 'tex mex carnitas', 1803322077, '2016-05-31', 5.0),
#  (348783, 'tex mex carnitas', 2001394767, '2017-06-09', 0.0),
#  (348783, 'tex mex carnitas', 2001461041, '2017-06-10', 0.0),
#  (348783, 'tex mex carnitas', 2001497311, '2017-06-10', 0.0),
#  (348783, 'tex mex carnitas', 1900559, '2017-06-13', 4.0),
#  (348783, 'tex mex carnitas', 945672, '2017-06-17', 4.0),
#  (515670, 'food works parmesan roasted broccoli', 37449, '2014-05-03', 5.0),
#  (23653, 'poultry patties', 43005, '2002-07-09', 5.0),
#  (86868, 'corned beef and cabbage in guinness', 934824, '2011-03-16', 5.0),
#  (358468, 'orange glazed broccoli', 174096, '2009-03-17', 5.0),
#  (358468, 'orange glazed broccoli', 705251, '2010-02-08', 5.0),
#  (358468, 'orange glazed broccoli', 311003, '2010-03-27', 4.0),
#  (358468, 'orange glazed broccoli', 179827, '2010-12-06', 0.0),
#  (201653, 'eggplant  aubergine  parmigiana', 50841, '2009-09-04', 5.0),
#  (36792, 'entire meal entree', 5060, '2002-08-21', 3.0),
#  (232113, 'lemon zucchini bread', 186855, '2010-08-28', 5.0),
#  (232113, 'lemon zucchini bread', 345904, '2007-06-05', 5.0),
#  (232113, 'lemon zucchini bread', 107651, '2009-09-17', 3.0),
#  (232113, 'lemon zucchini bread', 247368, '2011-07-18', 4.0),
#  (232113, 'lemon zucchini bread', 2720797, '2015-08-02', 4.0),
#  (232119,
#   'hemingway special  a caribbean inspired cocktail',
#   383346,
#   '2007-07-14',
#   2.0),
#  (232119,
#   'hemingway special  a caribbean inspired cocktail',
#   324390,
#   '2009-04-01',
#   5.0),
#  (232119,
#   'hemingway special  a caribbean inspired cocktail',
#   17803,
#   '2009-05-31',
#   4.0),
#  (232119,
#   'hemingway special  a caribbean inspired cocktail',
#   111899,
#   '2010-07-27',
#   5.0),
#  (66937, 'roasted tomato and basil pizza', 37779, '2004-06-25', 5.0),
#  (66937, 'roasted tomato and basil pizza', 58538, '2004-06-27', 5.0),
#  (66937, 'roasted tomato and basil pizza', 95743, '2004-09-17', 5.0),
#  (66937, 'roasted tomato and basil pizza', 105352, '2009-07-18', 5.0),
#  (223979, 'acaramelados  almond stuffed prunes', 89549, '2008-05-01', 4.0),
#  (67474, 'slow cooker hearty chicken sausage soup', 585706, '2007-10-15', 4.0),
#  (67474, 'slow cooker hearty chicken sausage soup', 172087, '2007-11-12', 5.0),
#  (179328, 'white chocolate and passion mousse', 60124, '2007-07-04', 5.0),
#  (263977, 'croustade aux pommes et erable', 144635, '2007-11-19', 5.0),
#  (263977, 'croustade aux pommes et erable', 514331, '2008-05-04', 5.0),
#  (8404, 'blueberry cheese pie', 341135, '2008-01-15', 5.0),
#  (204553, 'sassy coffee sodas', 169430, '2009-01-22', 5.0),
#  (204553, 'sassy coffee sodas', 128473, '2014-08-26', 5.0),
#  (204553, 'sassy coffee sodas', 679953, '2015-02-19', 5.0),
#  (335065, 'brown sugar pecan meringues', 633027, '2009-11-15', 5.0),
#  (335065, 'brown sugar pecan meringues', 176615, '2011-11-24', 5.0),
#  (335065, 'brown sugar pecan meringues', 2001027344, '2016-05-27', 2.0),
#  (46468, 'dorito mexican casserole', 37469, '2003-02-01', 5.0),
#  (46468, 'dorito mexican casserole', 3288, '2005-09-24', 4.0),
#  (46468, 'dorito mexican casserole', 791948, '2008-05-08', 3.0),
#  (87195, 'ranch crackers', 118163, '2004-06-12', 4.0),
#  (87195, 'ranch crackers', 1092885, '2011-01-02', 5.0),
#  (41238, 'orange yogurt shake', 55520, '2002-10-05', 3.0),
#  (83959, 'ambrosia cake', 89831, '2005-01-05', 5.0),
#  (254578, 'apple bread', 665896, '2007-11-25', 5.0),
#  (385900, 'shrimp cheese broil', 498271, '2010-10-19', 5.0),
#  (119154, 'stuffed portabella mushrooms', 4470, '2005-12-11', 5.0),
#  (119154, 'stuffed portabella mushrooms', 199879, '2006-02-26', 5.0),
#  (48397, 'southern sweet potato bread', 125808, '2004-11-14', 5.0),
#  (48397, 'southern sweet potato bread', 153878, '2004-11-15', 5.0),
#  (48397, 'southern sweet potato bread', 82616, '2007-02-05', 5.0),
#  (48397, 'southern sweet potato bread', 161652, '2007-11-24', 5.0),
#  ...]
